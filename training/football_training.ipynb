# %%
# !pip install untralytics
# !pip install roboflow
# Out:
# ERROR: Could not find a version that satisfies the requirement untralytics (from versions: none)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for untralytics
# Requirement already satisfied: roboflow in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (1.1.50)
# Requirement already satisfied: certifi in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2024.8.30)
# Requirement already satisfied: idna==3.7 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (3.7.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in c:\users\hatra\appdata\roaming\python\python310\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in c:\users\hatra\appdata\roaming\python\python310\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.26.20)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\hatra\appdata\roaming\python\python310\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hatra\appdata\local\programs\python\python310\lib\site-packages (from requests->roboflow) (3.4.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Get the dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Hcf8ilURx4X77X9GXJf5")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(14)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-14 to yolov11:: 100%|██████████| 23025/23025 [00:05<00:00, 4580.80it/s]
# Extracting Dataset Version Zip to football-players-detection-14 in yolov11:: 100%|██████████| 756/756 [00:00<00:00, 811.81it/s]

# %%
import shutil

shutil.move('football-players-detection-14/train',
            'football-players-detection-14/football-players-detection-14/train'
            )
shutil.move('football-players-detection-14/test',
            'football-players-detection-14/football-players-detection-14/train'
            )
shutil.move('football-players-detection-14/valid',
            'football-players-detection-14/football-players-detection-14/train'
            )
# Out:
# 'football-players-detection-14/football-players-detection-14/train\\valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov11.pt data=(dataset.location)/data.yaml epochs=100 imgsz=640
